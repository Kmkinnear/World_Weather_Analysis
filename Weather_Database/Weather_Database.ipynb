# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=639df5f78ac4e830f68987688330e593

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]       
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | porto walter
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 1 | alexandria
# Processing Record 8 of Set 1 | jacksonville
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | college
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | faanui
# Processing Record 17 of Set 1 | ewa beach
# Processing Record 18 of Set 1 | pangnirtung
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | navalmoral de la mata
# Processing Record 22 of Set 1 | tabas
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | santa elena
# Processing Record 27 of Set 1 | caluquembe
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | husavik
# Processing Record 30 of Set 1 | clyde river
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | altay
# Processing Record 33 of Set 1 | jaciara
# Processing Record 34 of Set 1 | klaksvik
# Processing Record 35 of Set 1 | tebingtinggi
# Processing Record 36 of Set 1 | baiyin
# Processing Record 37 of Set 1 | gallup
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | cap malheureux
# Processing Record 42 of Set 1 | la ronge
# Processing Record 43 of Set 1 | mandalgovi
# Processing Record 44 of Set 1 | vila velha
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | ayan
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | burgersdorp
# Processing Record 1 of Set 2 | bajo baudo
# City not found. Skipping...
# Processing Record 2 of Set 2 | dedovsk
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | coquimbo
# Processing Record 6 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 7 of Set 2 | lagoa
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | presidencia roque saenz pena
# Processing Record 10 of Set 2 | huarmey
# Processing Record 11 of Set 2 | kupino
# Processing Record 12 of Set 2 | zyryanka
# Processing Record 13 of Set 2 | muros
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | birjand
# Processing Record 16 of Set 2 | ketchikan
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | port hedland
# Processing Record 19 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 20 of Set 2 | cururupu
# Processing Record 21 of Set 2 | san patricio
# Processing Record 22 of Set 2 | north bend
# Processing Record 23 of Set 2 | carbonia
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | sarkand
# Processing Record 27 of Set 2 | naifaru
# Processing Record 28 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 2 | henties bay
# Processing Record 30 of Set 2 | nizhniy tsasuchey
# Processing Record 31 of Set 2 | kudahuvadhoo
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | nemuro
# Processing Record 34 of Set 2 | waingapu
# Processing Record 35 of Set 2 | burkburnett
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | katsuura
# Processing Record 38 of Set 2 | simao
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | vao
# Processing Record 41 of Set 2 | shellbrook
# Processing Record 42 of Set 2 | puerto baquerizo moreno
# Processing Record 43 of Set 2 | marzuq
# Processing Record 44 of Set 2 | port macquarie
# Processing Record 45 of Set 2 | namatanai
# Processing Record 46 of Set 2 | laguna
# Processing Record 47 of Set 2 | kutum
# Processing Record 48 of Set 2 | ucluelet
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | port hardy
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | cardston
# Processing Record 4 of Set 3 | kaitangata
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | poopo
# Processing Record 7 of Set 3 | shimoda
# Processing Record 8 of Set 3 | guerrero negro
# Processing Record 9 of Set 3 | cayenne
# Processing Record 10 of Set 3 | wanning
# Processing Record 11 of Set 3 | hailey
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 3 | bathsheba
# Processing Record 15 of Set 3 | inirida
# Processing Record 16 of Set 3 | lugovskiy
# City not found. Skipping...
# Processing Record 17 of Set 3 | gazojak
# Processing Record 18 of Set 3 | boa vista
# Processing Record 19 of Set 3 | caravelas
# Processing Record 20 of Set 3 | hambantota
# Processing Record 21 of Set 3 | eyl
# Processing Record 22 of Set 3 | aquidauana
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | porangatu
# Processing Record 25 of Set 3 | severnoye
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | padina
# Processing Record 29 of Set 3 | krasnoselkup
# Processing Record 30 of Set 3 | mahebourg
# Processing Record 31 of Set 3 | merauke
# Processing Record 32 of Set 3 | qaanaaq
# Processing Record 33 of Set 3 | shelburne
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | farah
# Processing Record 36 of Set 3 | umm kaddadah
# Processing Record 37 of Set 3 | aklavik
# Processing Record 38 of Set 3 | thohoyandou
# Processing Record 39 of Set 3 | staraya poltavka
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | osoyoos
# Processing Record 44 of Set 3 | havelock
# Processing Record 45 of Set 3 | esperance
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 3 | cruzeiro do sul
# Processing Record 49 of Set 3 | khani
# Processing Record 50 of Set 3 | hermanus
# Processing Record 1 of Set 4 | arboletes
# Processing Record 2 of Set 4 | hami
# Processing Record 3 of Set 4 | muroto
# Processing Record 4 of Set 4 | astana
# Processing Record 5 of Set 4 | rocha
# Processing Record 6 of Set 4 | jalu
# Processing Record 7 of Set 4 | leopoldina
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | mount isa
# Processing Record 10 of Set 4 | suluq
# Processing Record 11 of Set 4 | dingle
# Processing Record 12 of Set 4 | bluff
# Processing Record 13 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 4 | honiara
# Processing Record 15 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 4 | shingu
# Processing Record 17 of Set 4 | leningradskiy
# Processing Record 18 of Set 4 | turukhansk
# Processing Record 19 of Set 4 | mahajanga
# Processing Record 20 of Set 4 | xai-xai
# Processing Record 21 of Set 4 | geraldton
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | abu samrah
# Processing Record 24 of Set 4 | tuy hoa
# Processing Record 25 of Set 4 | fairbanks
# Processing Record 26 of Set 4 | chuy
# Processing Record 27 of Set 4 | biak
# Processing Record 28 of Set 4 | teknaf
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | miranda
# Processing Record 31 of Set 4 | narsaq
# Processing Record 32 of Set 4 | goderich
# Processing Record 33 of Set 4 | nakama
# Processing Record 34 of Set 4 | beringovskiy
# Processing Record 35 of Set 4 | manali
# Processing Record 36 of Set 4 | grindavik
# Processing Record 37 of Set 4 | beloha
# Processing Record 38 of Set 4 | tiksi
# Processing Record 39 of Set 4 | dikson
# Processing Record 40 of Set 4 | codrington
# Processing Record 41 of Set 4 | lebu
# Processing Record 42 of Set 4 | tougan
# Processing Record 43 of Set 4 | zelenets
# Processing Record 44 of Set 4 | airai
# Processing Record 45 of Set 4 | portobelo
# Processing Record 46 of Set 4 | saint-pierre
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | virginia beach
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | bhag
# Processing Record 1 of Set 5 | daru
# Processing Record 2 of Set 5 | badhni kalan
# Processing Record 3 of Set 5 | saint anthony
# Processing Record 4 of Set 5 | sergeyevka
# Processing Record 5 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 8 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 9 of Set 5 | pangai
# Processing Record 10 of Set 5 | lavrentiya
# Processing Record 11 of Set 5 | porto novo
# Processing Record 12 of Set 5 | panzhihua
# Processing Record 13 of Set 5 | ust-ishim
# Processing Record 14 of Set 5 | kohila
# Processing Record 15 of Set 5 | bam
# Processing Record 16 of Set 5 | argayash
# Processing Record 17 of Set 5 | chimbote
# Processing Record 18 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 5 | waddan
# Processing Record 20 of Set 5 | poum
# Processing Record 21 of Set 5 | andrews
# Processing Record 22 of Set 5 | mabaruma
# Processing Record 23 of Set 5 | yei
# Processing Record 24 of Set 5 | torbay
# Processing Record 25 of Set 5 | manturovo
# Processing Record 26 of Set 5 | maumere
# Processing Record 27 of Set 5 | artyshta
# Processing Record 28 of Set 5 | bubaque
# Processing Record 29 of Set 5 | mar del plata
# Processing Record 30 of Set 5 | rehoboth
# Processing Record 31 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 32 of Set 5 | isiolo
# Processing Record 33 of Set 5 | kizhinga
# Processing Record 34 of Set 5 | los llanos de aridane
# Processing Record 35 of Set 5 | nushki
# Processing Record 36 of Set 5 | yellowknife
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | necochea
# Processing Record 39 of Set 5 | methoni
# Processing Record 40 of Set 5 | egvekinot
# Processing Record 41 of Set 5 | coffs harbour
# Processing Record 42 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | saldanha
# Processing Record 44 of Set 5 | inhambane
# Processing Record 45 of Set 5 | amapa
# Processing Record 46 of Set 5 | berlevag
# Processing Record 47 of Set 5 | kavaratti
# Processing Record 48 of Set 5 | suntar
# Processing Record 49 of Set 5 | sharan
# Processing Record 50 of Set 5 | shibetsu
# Processing Record 1 of Set 6 | acapulco
# Processing Record 2 of Set 6 | lata
# Processing Record 3 of Set 6 | vestmannaeyjar
# Processing Record 4 of Set 6 | kisangani
# Processing Record 5 of Set 6 | ostrovnoy
# Processing Record 6 of Set 6 | saint cloud
# Processing Record 7 of Set 6 | richards bay
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | kandrian
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | apollonia
# Processing Record 12 of Set 6 | grand gaube
# Processing Record 13 of Set 6 | san cristobal
# Processing Record 14 of Set 6 | gorontalo
# Processing Record 15 of Set 6 | kindia
# Processing Record 16 of Set 6 | longyearbyen
# Processing Record 17 of Set 6 | moose factory
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | tumen
# Processing Record 20 of Set 6 | patancheru
# Processing Record 21 of Set 6 | yueyang
# Processing Record 22 of Set 6 | tura
# Processing Record 23 of Set 6 | stabat
# Processing Record 24 of Set 6 | awbari
# Processing Record 25 of Set 6 | katangli
# Processing Record 26 of Set 6 | cape girardeau
# Processing Record 27 of Set 6 | nurota
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | siverek
# Processing Record 30 of Set 6 | iqaluit
# Processing Record 31 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 6 | fortuna
# Processing Record 33 of Set 6 | upernavik
# Processing Record 34 of Set 6 | saraza
# Processing Record 35 of Set 6 | ribas do rio pardo
# Processing Record 36 of Set 6 | chumphon
# Processing Record 37 of Set 6 | samagaltay
# Processing Record 38 of Set 6 | ocos
# Processing Record 39 of Set 6 | rock hill
# Processing Record 40 of Set 6 | vila
# Processing Record 41 of Set 6 | sarangani
# Processing Record 42 of Set 6 | ponta delgada
# Processing Record 43 of Set 6 | aksarayskiy
# Processing Record 44 of Set 6 | bandarbeyla
# Processing Record 45 of Set 6 | arlit
# Processing Record 46 of Set 6 | nerchinskiy zavod
# Processing Record 47 of Set 6 | ladario
# Processing Record 48 of Set 6 | wagar
# Processing Record 49 of Set 6 | san quintin
# Processing Record 50 of Set 6 | sao felix do xingu
# Processing Record 1 of Set 7 | saint-augustin
# Processing Record 2 of Set 7 | ishigaki
# Processing Record 3 of Set 7 | aleksandrovskiy zavod
# Processing Record 4 of Set 7 | lashio
# Processing Record 5 of Set 7 | paamiut
# Processing Record 6 of Set 7 | palmerston
# Processing Record 7 of Set 7 | saint george
# Processing Record 8 of Set 7 | urengoy
# Processing Record 9 of Set 7 | flinders
# Processing Record 10 of Set 7 | ponta do sol
# Processing Record 11 of Set 7 | tuatapere
# Processing Record 12 of Set 7 | babu
# Processing Record 13 of Set 7 | loralai
# Processing Record 14 of Set 7 | veraval
# Processing Record 15 of Set 7 | great falls
# Processing Record 16 of Set 7 | alegria
# Processing Record 17 of Set 7 | chicama
# Processing Record 18 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 7 | new norfolk
# Processing Record 20 of Set 7 | severo-kurilsk
# Processing Record 21 of Set 7 | broome
# Processing Record 22 of Set 7 | batticaloa
# Processing Record 23 of Set 7 | uarini
# Processing Record 24 of Set 7 | ambilobe
# Processing Record 25 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 7 | rio grande
# Processing Record 28 of Set 7 | fayaoue
# Processing Record 29 of Set 7 | dunedin
# Processing Record 30 of Set 7 | tchollire
# Processing Record 31 of Set 7 | yaan
# Processing Record 32 of Set 7 | pacific grove
# Processing Record 33 of Set 7 | walvis bay
# Processing Record 34 of Set 7 | belaya gora
# Processing Record 35 of Set 7 | oranjestad
# Processing Record 36 of Set 7 | solnechnyy
# Processing Record 37 of Set 7 | livingston
# Processing Record 38 of Set 7 | ormara
# Processing Record 39 of Set 7 | amboise
# Processing Record 40 of Set 7 | oyama
# Processing Record 41 of Set 7 | vrangel
# Processing Record 42 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 7 | haines junction
# Processing Record 44 of Set 7 | prince rupert
# Processing Record 45 of Set 7 | anqing
# Processing Record 46 of Set 7 | mildura
# Processing Record 47 of Set 7 | maniitsoq
# Processing Record 48 of Set 7 | nanakuli
# Processing Record 49 of Set 7 | shentala
# Processing Record 50 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 8 | ephrata
# Processing Record 2 of Set 8 | flin flon
# Processing Record 3 of Set 8 | colares
# Processing Record 4 of Set 8 | praya
# Processing Record 5 of Set 8 | alakurtti
# Processing Record 6 of Set 8 | santa maria
# Processing Record 7 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 8 of Set 8 | bud
# Processing Record 9 of Set 8 | ask
# Processing Record 10 of Set 8 | sola
# Processing Record 11 of Set 8 | waipawa
# Processing Record 12 of Set 8 | atagay
# Processing Record 13 of Set 8 | ostuacan
# Processing Record 14 of Set 8 | kodiak
# Processing Record 15 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 16 of Set 8 | paoua
# Processing Record 17 of Set 8 | skibbereen
# Processing Record 18 of Set 8 | luanda
# Processing Record 19 of Set 8 | makokou
# Processing Record 20 of Set 8 | ixtapa
# Processing Record 21 of Set 8 | kitimat
# Processing Record 22 of Set 8 | dauphin
# Processing Record 23 of Set 8 | lamu
# Processing Record 24 of Set 8 | yerbogachen
# Processing Record 25 of Set 8 | jiazi
# Processing Record 26 of Set 8 | hohhot
# Processing Record 27 of Set 8 | singkang
# Processing Record 28 of Set 8 | diamantino
# Processing Record 29 of Set 8 | ilinge
# Processing Record 30 of Set 8 | show low
# Processing Record 31 of Set 8 | san pedro
# Processing Record 32 of Set 8 | marabba
# Processing Record 33 of Set 8 | talnakh
# Processing Record 34 of Set 8 | deputatskiy
# Processing Record 35 of Set 8 | maxixe
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | korla
# Processing Record 38 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 8 | yulara
# Processing Record 41 of Set 8 | cidreira
# Processing Record 42 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 8 | palmaner
# Processing Record 44 of Set 8 | levin
# Processing Record 45 of Set 8 | kodinsk
# Processing Record 46 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 47 of Set 8 | tanout
# Processing Record 48 of Set 8 | srednekolymsk
# Processing Record 49 of Set 8 | imeni poliny osipenko
# Processing Record 50 of Set 8 | sicuani
# Processing Record 1 of Set 9 | ribeira grande
# Processing Record 2 of Set 9 | svetlogorsk
# Processing Record 3 of Set 9 | morondava
# Processing Record 4 of Set 9 | marawi
# Processing Record 5 of Set 9 | diffa
# Processing Record 6 of Set 9 | pleasant prairie
# Processing Record 7 of Set 9 | port lincoln
# Processing Record 8 of Set 9 | kampot
# Processing Record 9 of Set 9 | krabi
# Processing Record 10 of Set 9 | mocuba
# Processing Record 11 of Set 9 | tallahassee
# Processing Record 12 of Set 9 | nabire
# Processing Record 13 of Set 9 | gull lake
# Processing Record 14 of Set 9 | nalut
# Processing Record 15 of Set 9 | rosetta
# Processing Record 16 of Set 9 | mbandaka
# Processing Record 17 of Set 9 | nanyamba
# Processing Record 18 of Set 9 | vanavara
# Processing Record 19 of Set 9 | peleduy
# Processing Record 20 of Set 9 | vitimskiy
# City not found. Skipping...
# Processing Record 21 of Set 9 | tsumeb
# Processing Record 22 of Set 9 | les cayes
# Processing Record 23 of Set 9 | vestmanna
# Processing Record 24 of Set 9 | grenada
# Processing Record 25 of Set 9 | izhmorskiy
# Processing Record 26 of Set 9 | kloulklubed
# Processing Record 27 of Set 9 | camacha
# Processing Record 28 of Set 9 | pirgos
# Processing Record 29 of Set 9 | samarai
# Processing Record 30 of Set 9 | georgiyevskoye
# Processing Record 31 of Set 9 | vardo
# Processing Record 32 of Set 9 | mount dora
# Processing Record 33 of Set 9 | itarema
# Processing Record 34 of Set 9 | vanderhoof
# Processing Record 35 of Set 9 | yumen
# Processing Record 36 of Set 9 | jumla
# Processing Record 37 of Set 9 | zuwarah
# Processing Record 38 of Set 9 | komsomolskiy
# Processing Record 39 of Set 9 | cabo san lucas
# Processing Record 40 of Set 9 | belyy yar
# Processing Record 41 of Set 9 | salalah
# Processing Record 42 of Set 9 | cascais
# Processing Record 43 of Set 9 | hualmay
# Processing Record 44 of Set 9 | keokuk
# Processing Record 45 of Set 9 | changli
# Processing Record 46 of Set 9 | sidney
# Processing Record 47 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 9 | taltal
# Processing Record 49 of Set 9 | sitka
# Processing Record 50 of Set 9 | fare
# Processing Record 1 of Set 10 | ust-nera
# Processing Record 2 of Set 10 | antalaha
# Processing Record 3 of Set 10 | tobol
# Processing Record 4 of Set 10 | podolsk
# Processing Record 5 of Set 10 | fukue
# Processing Record 6 of Set 10 | portland
# Processing Record 7 of Set 10 | xam nua
# Processing Record 8 of Set 10 | muyezerskiy
# Processing Record 9 of Set 10 | sidi ali
# Processing Record 10 of Set 10 | nome
# Processing Record 11 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 10 | puerto escondido
# Processing Record 13 of Set 10 | bichena
# Processing Record 14 of Set 10 | ninotsminda
# Processing Record 15 of Set 10 | luderitz
# Processing Record 16 of Set 10 | evensk
# Processing Record 17 of Set 10 | avera
# Processing Record 18 of Set 10 | tres arroyos
# Processing Record 19 of Set 10 | khakhea
# Processing Record 20 of Set 10 | praxedis guerrero
# Processing Record 21 of Set 10 | saint-louis
# Processing Record 22 of Set 10 | garm
# City not found. Skipping...
# Processing Record 23 of Set 10 | ust-kalmanka
# Processing Record 24 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 10 | simbahan
# Processing Record 26 of Set 10 | narasannapeta
# Processing Record 27 of Set 10 | bafq
# Processing Record 28 of Set 10 | general pico
# Processing Record 29 of Set 10 | suita
# Processing Record 30 of Set 10 | hangzhou
# Processing Record 31 of Set 10 | meulaboh
# Processing Record 32 of Set 10 | port shepstone
# Processing Record 33 of Set 10 | sakakah
# Processing Record 34 of Set 10 | soyo
# Processing Record 35 of Set 10 | kahului
# Processing Record 36 of Set 10 | vila franca do campo
# Processing Record 37 of Set 10 | kruisfontein
# Processing Record 38 of Set 10 | sistranda
# Processing Record 39 of Set 10 | omsukchan
# Processing Record 40 of Set 10 | tomatlan
# Processing Record 41 of Set 10 | olafsvik
# Processing Record 42 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 10 | kirakira
# Processing Record 44 of Set 10 | puri
# Processing Record 45 of Set 10 | lloydminster
# Processing Record 46 of Set 10 | zehdenick
# Processing Record 47 of Set 10 | guymon
# Processing Record 48 of Set 10 | nanortalik
# Processing Record 49 of Set 10 | rincon
# Processing Record 50 of Set 10 | manaus
# Processing Record 1 of Set 11 | pitea
# Processing Record 2 of Set 11 | oum hadjer
# Processing Record 3 of Set 11 | kropotkin
# Processing Record 4 of Set 11 | gornyy
# Processing Record 5 of Set 11 | sorland
# Processing Record 6 of Set 11 | galveston
# Processing Record 7 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 11 | labuhan
# Processing Record 9 of Set 11 | tiznit
# Processing Record 10 of Set 11 | elizabeth city
# Processing Record 11 of Set 11 | batangafo
# Processing Record 12 of Set 11 | alofi
# Processing Record 13 of Set 11 | porto belo
# Processing Record 14 of Set 11 | thatcham
# Processing Record 15 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 16 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 11 | laramie
# Processing Record 18 of Set 11 | karoi
# Processing Record 19 of Set 11 | liling
# Processing Record 20 of Set 11 | bambanglipuro
# Processing Record 21 of Set 11 | mumford
# Processing Record 22 of Set 11 | mayumba
# Processing Record 23 of Set 11 | leiyang
# Processing Record 24 of Set 11 | hobyo
# Processing Record 25 of Set 11 | kalabo
# Processing Record 26 of Set 11 | elat
# Processing Record 27 of Set 11 | belokurikha
# Processing Record 28 of Set 11 | anadyr
# Processing Record 29 of Set 11 | sandwich
# Processing Record 30 of Set 11 | isangel
# Processing Record 31 of Set 11 | kuching
# Processing Record 32 of Set 11 | camocim
# Processing Record 33 of Set 11 | nuuk
# Processing Record 34 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 11 | santa marta
# Processing Record 36 of Set 11 | byron bay
# Processing Record 37 of Set 11 | sain alto
# Processing Record 38 of Set 11 | praia da vitoria
# Processing Record 39 of Set 11 | lompoc
# Processing Record 40 of Set 11 | thinadhoo
# Processing Record 41 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 42 of Set 11 | rio cuarto
# Processing Record 43 of Set 11 | saint-georges
# Processing Record 44 of Set 11 | emerald
# Processing Record 45 of Set 11 | alyangula
# Processing Record 46 of Set 11 | sioux lookout
# Processing Record 47 of Set 11 | okhotsk
# Processing Record 48 of Set 11 | elko
# Processing Record 49 of Set 11 | bartica
# Processing Record 50 of Set 11 | omutinskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | road town
# Processing Record 2 of Set 12 | arrifes
# Processing Record 3 of Set 12 | cauquenes
# Processing Record 4 of Set 12 | sainte-suzanne
# Processing Record 5 of Set 12 | doha
# Processing Record 6 of Set 12 | ejido
# Processing Record 7 of Set 12 | getulio vargas
# Processing Record 8 of Set 12 | klyuchi
# Processing Record 9 of Set 12 | villa guerrero
# Processing Record 10 of Set 12 | ginir
# Processing Record 11 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 12 of Set 12 | lilongwe
# Processing Record 13 of Set 12 | agadez
# Processing Record 14 of Set 12 | channel-port aux basques
# Processing Record 15 of Set 12 | panguna
# Processing Record 16 of Set 12 | aberdeen
# Processing Record 17 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 18 of Set 12 | barsovo
# Processing Record 19 of Set 12 | khasan
# Processing Record 20 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 12 | sarakhs
# Processing Record 22 of Set 12 | santa fe
# Processing Record 23 of Set 12 | fulton
# Processing Record 24 of Set 12 | herrin
# Processing Record 25 of Set 12 | maneromango
# Processing Record 26 of Set 12 | faya
# Processing Record 27 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 12 | marrakesh
# Processing Record 29 of Set 12 | elbistan
# Processing Record 30 of Set 12 | boyolangu
# Processing Record 31 of Set 12 | prescott
# Processing Record 32 of Set 12 | giovinazzo
# Processing Record 33 of Set 12 | omaruru
# Processing Record 34 of Set 12 | alice springs
# Processing Record 35 of Set 12 | qaqortoq
# Processing Record 36 of Set 12 | madison heights
# Processing Record 37 of Set 12 | awjilah
# Processing Record 38 of Set 12 | miguel auza
# Processing Record 39 of Set 12 | teguldet
# Processing Record 40 of Set 12 | phirangipuram
# Processing Record 41 of Set 12 | yarada
# Processing Record 42 of Set 12 | mercedes
# Processing Record 43 of Set 12 | sandata
# Processing Record 44 of Set 12 | leh
# Processing Record 45 of Set 12 | srivardhan
# Processing Record 46 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 47 of Set 12 | pishin
# Processing Record 48 of Set 12 | sant feliu de guixols
# Processing Record 49 of Set 12 | nizhniy kuranakh
# Processing Record 50 of Set 12 | balkanabat
# Processing Record 1 of Set 13 | juneau
# Processing Record 2 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 3 of Set 13 | bousso
# Processing Record 4 of Set 13 | mazagao
# Processing Record 5 of Set 13 | batagay
# Processing Record 6 of Set 13 | aalen
# Processing Record 7 of Set 13 | troitsko-pechorsk
# Processing Record 8 of Set 13 | mattru
# Processing Record 9 of Set 13 | hamilton
# Processing Record 10 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 11 of Set 13 | nanlong
# Processing Record 12 of Set 13 | baykit
# Processing Record 13 of Set 13 | nayudupeta
# Processing Record 14 of Set 13 | ossora
# Processing Record 15 of Set 13 | san rafael
# Processing Record 16 of Set 13 | pitkyaranta
# Processing Record 17 of Set 13 | goure
# Processing Record 18 of Set 13 | matadi
# Processing Record 19 of Set 13 | tacoronte
# Processing Record 20 of Set 13 | sao joao da barra
# Processing Record 21 of Set 13 | mount gambier
# Processing Record 22 of Set 13 | glarus
# Processing Record 23 of Set 13 | gushikawa
# Processing Record 24 of Set 13 | wolomin
# Processing Record 25 of Set 13 | brae
# Processing Record 26 of Set 13 | santiago de chuco
# Processing Record 27 of Set 13 | iwanai
# Processing Record 28 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 13 | namibe
# Processing Record 30 of Set 13 | kushiro
# Processing Record 31 of Set 13 | ternate
# Processing Record 32 of Set 13 | kununurra
# Processing Record 33 of Set 13 | gat
# Processing Record 34 of Set 13 | kalaikunda
# Processing Record 35 of Set 13 | kalianget
# Processing Record 36 of Set 13 | dukat
# Processing Record 37 of Set 13 | san luis
# Processing Record 38 of Set 13 | beruni
# City not found. Skipping...
# Processing Record 39 of Set 13 | bairiki
# Processing Record 40 of Set 13 | manado
# Processing Record 41 of Set 13 | bac lieu
# Processing Record 42 of Set 13 | vostok
# Processing Record 43 of Set 13 | rio branco
# Processing Record 44 of Set 13 | dergaon
# Processing Record 45 of Set 13 | planeta rica
# Processing Record 46 of Set 13 | yako
# Processing Record 47 of Set 13 | manzanillo
# Processing Record 48 of Set 13 | lafia
# Processing Record 49 of Set 13 | beyneu
# Processing Record 50 of Set 13 | tocopilla
# Processing Record 1 of Set 14 | tucurui
# Processing Record 2 of Set 14 | lasa
# Processing Record 3 of Set 14 | khuzdar
# Processing Record 4 of Set 14 | monastyrshchina
# Processing Record 5 of Set 14 | denpasar
# Processing Record 6 of Set 14 | alirajpur
# Processing Record 7 of Set 14 | oistins
# Processing Record 8 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 9 of Set 14 | myitkyina
# Processing Record 10 of Set 14 | chilca
# Processing Record 11 of Set 14 | chapleau
# Processing Record 12 of Set 14 | ersekvadkert
# Processing Record 13 of Set 14 | poya
# Processing Record 14 of Set 14 | abha
# Processing Record 15 of Set 14 | lodeynoye pole
# Processing Record 16 of Set 14 | teluknaga
# Processing Record 17 of Set 14 | eureka
# Processing Record 18 of Set 14 | mega
# Processing Record 19 of Set 14 | nagato
# Processing Record 20 of Set 14 | abu zabad
# Processing Record 21 of Set 14 | quelimane
# Processing Record 22 of Set 14 | te anau
# Processing Record 23 of Set 14 | sai buri
# Processing Record 24 of Set 14 | samana
# Processing Record 25 of Set 14 | revadanda
# Processing Record 26 of Set 14 | sabha
# Processing Record 27 of Set 14 | bilibino
# Processing Record 28 of Set 14 | zhezkazgan
# Processing Record 29 of Set 14 | mawlaik
# Processing Record 30 of Set 14 | tutoia
# Processing Record 31 of Set 14 | badou
# Processing Record 32 of Set 14 | ilulissat
# Processing Record 33 of Set 14 | zhangye
# Processing Record 34 of Set 14 | mayo
# Processing Record 35 of Set 14 | pangody
# Processing Record 36 of Set 14 | baikunthpur
# Processing Record 37 of Set 14 | atar
# Processing Record 38 of Set 14 | moratuwa
# Processing Record 39 of Set 14 | sainte-marie
# Processing Record 40 of Set 14 | coatlan
# City not found. Skipping...
# Processing Record 41 of Set 14 | ambunti
# Processing Record 42 of Set 14 | cape canaveral
# Processing Record 43 of Set 14 | ratholo
# Processing Record 44 of Set 14 | nizip
# Processing Record 45 of Set 14 | chateauroux
# Processing Record 46 of Set 14 | vaitape
# Processing Record 47 of Set 14 | buchanan
# Processing Record 48 of Set 14 | miracatu
# Processing Record 49 of Set 14 | mnogovershinnyy
# Processing Record 50 of Set 14 | charters towers
# Processing Record 1 of Set 15 | yar-sale
# Processing Record 2 of Set 15 | whitehorse
# Processing Record 3 of Set 15 | tayoltita
# Processing Record 4 of Set 15 | villarrica
# Processing Record 5 of Set 15 | magog
# Processing Record 6 of Set 15 | ha tinh
# Processing Record 7 of Set 15 | pundaguitan
# Processing Record 8 of Set 15 | otjimbingwe
# Processing Record 9 of Set 15 | taranagar
# Processing Record 10 of Set 15 | san carlos de bariloche
# Processing Record 11 of Set 15 | basco
# Processing Record 12 of Set 15 | sabang
# Processing Record 13 of Set 15 | upington
# Processing Record 14 of Set 15 | suhbaatar
# Processing Record 15 of Set 15 | key west
# Processing Record 16 of Set 15 | quatre cocos
# Processing Record 17 of Set 15 | treinta y tres
# Processing Record 18 of Set 15 | oktyabrskoye
# Processing Record 19 of Set 15 | ahipara
# Processing Record 20 of Set 15 | huilong
# Processing Record 21 of Set 15 | bondo
# Processing Record 22 of Set 15 | buala
# Processing Record 23 of Set 15 | tautira
# Processing Record 24 of Set 15 | carauari
# Processing Record 25 of Set 15 | metro
# Processing Record 26 of Set 15 | chateaubelair
# Processing Record 27 of Set 15 | ontario
# Processing Record 28 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 29 of Set 15 | fort collins
# Processing Record 30 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 15 | qujing
# Processing Record 32 of Set 15 | porto velho
# Processing Record 33 of Set 15 | sisimiut
# Processing Record 34 of Set 15 | gornozavodsk
# Processing Record 35 of Set 15 | jiangyou
# Processing Record 36 of Set 15 | innisfail
# Processing Record 37 of Set 15 | broken hill
# Processing Record 38 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 15 | helong
# Processing Record 40 of Set 15 | santa isabel do rio negro
# Processing Record 41 of Set 15 | yima
# Processing Record 42 of Set 15 | muisne
# Processing Record 43 of Set 15 | masvingo
# Processing Record 44 of Set 15 | muli
# Processing Record 45 of Set 15 | agstafa
# City not found. Skipping...
# Processing Record 46 of Set 15 | tilichiki
# Processing Record 47 of Set 15 | san giovanni in fiore
# Processing Record 48 of Set 15 | mombetsu
# Processing Record 49 of Set 15 | mangaldai
# Processing Record 50 of Set 15 | gornopravdinsk
# Processing Record 1 of Set 16 | dudinka
# Processing Record 2 of Set 16 | banff
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro      BR -24.7911  -50.0119     59.95        94         100
# 1    Butaritari      KI   3.0707  172.7902     80.87        74          64
# 2  Porto Walter      BR  -8.2686  -72.7439     72.57        97         100
# 3     Busselton      AU -33.6500  115.3333     48.99        84          93
# 4    Alexandria      EG  31.2156   29.9553     77.07        68          75
# 5  Jacksonville      US  30.3322  -81.6556     82.06        53           0
# 6      Bengkulu      ID  -3.8004  102.2655     76.14        89         100
# 7       Ushuaia      AR -54.8000  -68.3000     49.62        49          20
# 8  Punta Arenas      CL -53.1500  -70.9167     48.31        49           0
# 9        Atuona      PF  -9.8000 -139.0333     76.42        72          12
#
#    Wind Speed Current Description
# 0       10.33          light rain
# 1       19.66       broken clouds
# 2        2.37     overcast clouds
# 3        8.43     overcast clouds
# 4       12.19       broken clouds
# 5       11.50           clear sky
# 6        4.05          light rain
# 7       24.16          few clouds
# 8       21.85           clear sky
# 9       15.66          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro      BR -24.7911  -50.0119     59.95        94         100
# 1    Butaritari      KI   3.0707  172.7902     80.87        74          64
# 2  Porto Walter      BR  -8.2686  -72.7439     72.57        97         100
# 3     Busselton      AU -33.6500  115.3333     48.99        84          93
# 4    Alexandria      EG  31.2156   29.9553     77.07        68          75
#
#    Wind Speed Current Description
# 0       10.33          light rain
# 1       19.66       broken clouds
# 2        2.37     overcast clouds
# 3        8.43     overcast clouds
# 4       12.19       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-02de294f544c> in <module>
#       3
#       4 # Export the City_Data into a CSV.
# ----> 5 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_database/WeatherPy_Database.csv'
